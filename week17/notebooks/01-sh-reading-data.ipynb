# %%
import pandas as pd

# %%
import os

os.getcwd()
# Out:
# '/Users/shaq/Documents/waia-academy/Sep-Bootcamp/week17/notebooks'

# %%
# read and "analyse" the users data pickle file

users_data = pd.read_pickle("../data/users_data_final.pkl")

# %%
type(users_data)
# Out:
# pandas.core.frame.DataFrame

# %%
users_data.shape
# Out:
# (45209, 19)

# %%
users_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 45209 entries, 0 to 45215
# Data columns (total 19 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   user_id              45209 non-null  object
#  1   number_transactions  35210 non-null  float64
#  2   total_amount_usd     35210 non-null  float64
#  3   age                  45209 non-null  int64
#  4   job                  44921 non-null  object
#  5   marital              45209 non-null  object
#  6   education            43352 non-null  object
#  7   default              45209 non-null  bool
#  8   housing              45209 non-null  bool
#  9   loan                 45209 non-null  bool
#  10  contact              32191 non-null  object
#  11  duration             45209 non-null  int64
#  12  campaign             45209 non-null  int64
#  13  pdays                45209 non-null  int64
#  14  previous             45209 non-null  int64
# ...

# %%
users_data.head()
# Out:
#                                 user_id  number_transactions  \
# 0  9231c446-cb16-4b2b-a7f7-ddfc8b25aaf6                  3.0
# 1  bb92765a-08de-4963-b432-496524b39157                  NaN
# 2  573de577-49ef-42b9-83da-d3cfb817b5c1                  2.0
# 3  d6b66b9d-7c8f-4257-a682-e136f640b7e3                  NaN
# 4  fade0b20-7594-4d9a-84cd-c02f79b1b526                  1.0
#
#    total_amount_usd  age           job  marital  education  default  housing  \
# 0            2143.0   58    management  married   tertiary    False     True
# 1               NaN   44    technician   single  secondary    False     True
# 2               2.0   33  entrepreneur  married  secondary    False     True
# 3               NaN   47   blue-collar  married       None    False     True
# 4               1.0   33          None   single       None    False    False
#
#     loan contact  duration  campaign  pdays  previous poutcome  term_deposit  \
# ...

# %%
# read and analyse the .csv file

audio_data = pd.read_csv("../data/audio_data_w_features.csv")

# %%
type(audio_data)
# Out:
# pandas.core.frame.DataFrame

# %%
audio_data.shape
# Out:
# (30, 3)

# %%
audio_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   audio_file_name     30 non-null     object
#  1   zero_crossing_rate  30 non-null     int64
#  2   energy              30 non-null     float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 852.0+ bytes

# %%
audio_data.head()
# Out:
#   audio_file_name  zero_crossing_rate      energy
# 0  classical1.wav               35019   33.268707
# 1     marlene.wav               53817   52.843853
# 2     hendrix.wav               62196   75.526360
# 3     beatles.wav               23928   84.270905
# 4    birdland.wav               77597  111.841644

# %%
# read the sample data file

sample_data = pd.read_excel("../data/file_example_XLSX_50.xlsx")

# %%
type(sample_data)
# Out:
# pandas.core.frame.DataFrame

# %%
sample_data.shape
# Out:
# (50, 8)

# %%
sample_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   0           50 non-null     int64
#  1   First Name  50 non-null     object
#  2   Last Name   50 non-null     object
#  3   Gender      50 non-null     object
#  4   Country     50 non-null     object
#  5   Age         50 non-null     int64
#  6   Date        50 non-null     object
#  7   Id          50 non-null     int64
# dtypes: int64(3), object(5)
# memory usage: 3.3+ KB

# %%
sample_data.head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
# drop the column 0
sample_data.drop([0], axis=1)
# Out:
#    First Name   Last Name  Gender        Country  Age        Date    Id
# 0       Dulce       Abril  Female  United States   32  15/10/2017  1562
# 1        Mara   Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2      Philip        Gent    Male         France   36  21/05/2015  2587
# 3    Kathleen      Hanner  Female  United States   25  15/10/2017  3549
# 4     Nereida     Magwood  Female  United States   58  16/08/2016  2468
# 5      Gaston       Brumm    Male  United States   24  21/05/2015  2554
# 6        Etta        Hurn  Female  Great Britain   56  15/10/2017  3598
# 7     Earlean      Melgar  Female  United States   27  16/08/2016  2456
# 8    Vincenza     Weiland  Female  United States   40  21/05/2015  6548
# 9      Fallon     Winward  Female  Great Britain   28  16/08/2016  5486
# 10    Arcelia      Bouska  Female  Great Britain   39  21/05/2015  1258
# 11   Franklyn      Unknow    Male         France   38  15/10/2017  2579
# ...

# %%
sample_data.head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
# option 1 to drop a column
sample_data_cleaned = sample_data.drop([0], axis=1)

# %%
sample_data_cleaned.head()
# Out:
#   First Name  Last Name  Gender        Country  Age        Date    Id
# 0      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2     Philip       Gent    Male         France   36  21/05/2015  2587
# 3   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
# option 2 to drop a column
sample_data.drop([0], axis=1, inplace=True)

# %%
sample_data.head()
# Out:
#   First Name  Last Name  Gender        Country  Age        Date    Id
# 0      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2     Philip       Gent    Male         France   36  21/05/2015  2587
# 3   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
# read the sample data file again - which has the 0 column

sample_data = pd.read_excel("../data/file_example_XLSX_50.xlsx")
sample_data.head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
# drop 0 from the sample data
sample_data_cleaned = sample_data.drop([0], axis=1)
sample_data_cleaned.head()
# Out:
#   First Name  Last Name  Gender        Country  Age        Date    Id
# 0      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2     Philip       Gent    Male         France   36  21/05/2015  2587
# 3   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
# create a new file with the change
# index = False prevents an additional column being created

sample_data_cleaned.to_csv("../data/file_example_XLSX_50_cleaned.csv", index=False)

# %%
# read the new file

pd.read_csv("../data/file_example_XLSX_50_cleaned.csv").head()
# Out:
#   First Name  Last Name  Gender        Country  Age        Date    Id
# 0      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2     Philip       Gent    Male         France   36  21/05/2015  2587
# 3   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
# read the original file
pd.read_excel("../data/file_example_XLSX_50.xlsx").head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
# put all the steps together

# read the data
sample_data = pd.read_excel("../data/file_example_XLSX_50.xlsx")
sample_data.head()
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
# transformation task - drop the 0 column
sample_data_cleaned = sample_data.drop([0], axis=1)
sample_data_cleaned.head()
# Out:
#   First Name  Last Name  Gender        Country        Date    Id
# 0      Dulce      Abril  Female  United States  15/10/2017  1562
# 1       Mara  Hashimoto  Female  Great Britain  16/08/2016  1582
# 2     Philip       Gent    Male         France  21/05/2015  2587
# 3   Kathleen     Hanner  Female  United States  15/10/2017  3549
# 4    Nereida    Magwood  Female  United States  16/08/2016  2468

# %%
# load to the data folder - write as a csv file. Dont forget to add index=False
sample_data_cleaned.to_csv("../data/file_example_XLSX_50_cleaned.csv", index=False)

# %%
# write as an excel file

sample_data_cleaned.to_excel("../data/file_example_XLSX_50_cleaned.xlsx", index=False)

# %%
# check to see if everything works as expected
pd.read_csv("../data/file_example_XLSX_50_cleaned.csv").head()
# Out:
#   First Name  Last Name  Gender        Country  Age        Date    Id
# 0      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2     Philip       Gent    Male         France   36  21/05/2015  2587
# 3   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4    Nereida    Magwood  Female  United States   58  16/08/2016  2468

# %%
# check to see if everything works as expected
pd.read_excel("../data/file_example_XLSX_50_cleaned.xlsx").head()
# Out:
#   First Name  Last Name  Gender        Country        Date    Id
# 0      Dulce      Abril  Female  United States  15/10/2017  1562
# 1       Mara  Hashimoto  Female  Great Britain  16/08/2016  1582
# 2     Philip       Gent    Male         France  21/05/2015  2587
# 3   Kathleen     Hanner  Female  United States  15/10/2017  3549
# 4    Nereida    Magwood  Female  United States  16/08/2016  2468
